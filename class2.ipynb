# %% [raw]
# #Operators

# %%
#Aithmetic

# %%
a=3
b=2

# %%
#Arithmetic
print(a+b)
print(a-b)
print(a*b)
print(a**b)
print(a/b)
print(a%b) #reminder
print(a//b) #quotient
# Out:
# 5
# 1
# 6
# 9
# 1.5
# 1
# 1

# %%
#Assigmnet Operators
b=3
a = b
print(a)
a **=b
print(a)
a += b
print(a)
a -= b
print(a)
a *= b
print(a)
a /= b
print(a)
a %= b
print(a)
a //= b
print(a)
a **= b
print(a)
# Out:
# 3
# 27
# 30
# 27
# 81
# 27.0
# 0.0
# 0.0
# 0.0

# %%
#Comparision Operators
a=3
b=2
print(a==b)
print(a!=b)
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
# Out:
# 0
# False
# True
# True
# False
# True
# False

# %%
#LOGICAL Operators
a=2
b=3
print(a==3 and b==3)
print(a or b)
# Out:
# False
# 2

# %%
a = 10 0101
b = 4 0010

print(a & b)
print(a | b)
print(~a)
print(a ^ b)
print(a >> 2)
print(a << 2)
# Out:
# 0
# 14
# -11
# 14
# 2
# 40

# %%
['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']#35

# %%
if i ==3:
    True

# %%
#DataStructurs
Str='Srujana'
#index:0123456
#index:-7     -2-1
#slicing
print(Str[:5:3])
#[start:stop:step]
# Out:
# Sj

# %%
s="hello world!rat,father"
print(s.capitalize())
print(s.replace('rat','ran'))
print(s.index('r'))
#TO DO:To know how to find second repeating index
# Out:
# Hello world!rat,father
# hello world!ran,father
# 8

# %%
#String
s="hello!world!rat,father"
p=['hello','world','rat','father']
  #01234

print(len(s))
print(s.upper())
print(s.lower())
print(s.title())
print(s.count('o'))
print(s.strip())
print(s.rstrip())
print(s.lstrip())
print(s.split('!'))
print(s.capitalize())
" ".join(p)
# Out:
# 22
# HELLO!WORLD!RAT,FATHER
# hello!world!rat,father
# Hello!World!Rat,Father
# 2
# hello!world!rat,father
# hello!world!rat,father
# hello!world!rat,father
# ['hello', 'world', 'rat,father']
# Hello!world!rat,father
# 'hello world rat father'

# %%
'''str.startswith(prefix)	Checks if string starts with prefix	"hello".startswith("he") → True
str.endswith(suffix)	Checks if string ends with suffix	"hello".endswith("lo") → True
str.isalpha()	True if all chars are letters	"abc".isalpha() → True
str.isdigit()	True if all chars are digits	"123".isdigit() → True
str.isalnum()	True if all chars are letters or digits	"abc123".isalnum() → True
str.isspace()	True if all chars are whitespace	" ".isspace() → True
str.swapcase()	Swaps case of each letter	"Hello".swapcase() → "hELLO"
str.zfill(width)'''
#s.startswith('he')
#s.endswith('father')
# d='Grow'
# d.isalpha()
e='we2'
# e.isdigit()
# e.isalnum()
s='Hello!World!Rat,Father'
# s.swapcase()
print(s.zfill(2))
# Out:
# Hello!World!Rat,Father

# %%
#slicing
s="hello world rat"
# #012345
#             -3-2-1
print(s[2])
print(s[2:7])
print(s[:])
print(s[3:])
print(s[:10])
print(s[::2])
#start:stop:step
print(s[::3])
print(s[::-1])
print(s[-3:-1])
s1='rat'
s2='cat'
print(s1+'!'+s2)
# Out:
# l
# llo w
# hello world rat
# lo world rat
# hello worl
# hlowrdrt
# hlwlr
# tar dlrow olleh
# ra
# rat!cat

# %%
print(s[-8:-1])
s="Strng"
print(s[::-1])
if s == s[::-1]:
    print('is_palindrome')
else:
    print(False)
# Out:
# Strn
# gnrtS
# False

# %%
p=['hello','world','rat']
print(','.join(p))
print(' '.join(p))
print(''.join(p))
print('-'.join(p))
# Out:
# hello,world,rat
# hello world rat
# helloworldrat
# hello-world-rat

# %%
s1='sat'
s2=32
s3=s1+s2
print(s3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 3
#       1 s1='sat'
#       2 s2=32
# ----> 3 s3=s1+s2
#       4 print(s3)
#
# TypeError: can only concatenate str (not "int") to str
